# %%
# !pip install Pillow

# %%
from PIL import Image, ImageEnhance

# %%
img = Image.open('imagens/DKC2.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=957x436 at 0x23C921C6730>

# %%
dim = (100, 200, 300, 250)
crop_img = img.crop(dim)

# %%
crop_img
# Out:
# <PIL.Image.Image image mode=RGB size=200x50 at 0x23C9337AEE0>

# %%
dim2 = (100, 100, 400, 400)
crop_img = img.crop(dim2)
crop_img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x23C932EBB80>
